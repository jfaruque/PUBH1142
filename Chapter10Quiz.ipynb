# %% [markdown]
# Summary
# * use the hue argument to est. diff colors (categorical vars) in your plots
# * relational plots (correlation)
#     * seaborn.scatterplot();
#     * range(start, end, stepsize)
#     * set()
#     * pyplot.legend()
# * distributional plots (histograms, frequency)
#     * seaborn.displot()
#     * set()
#     * multiple argument
#     * col argument
#     * stat = 'probability' for relative frequency
#     * relative frequency is a prop/perc of something happening with the total in mind
# * review types of var: numerical vs categorical, discrete vs continuous
# * heat maps to visualize distribution of 2 cont var
#     * add a y variable to the displot() to create this
#     * cbar argument
# * ask about the heat areas in next class
# * jointplot() for combining diff visualizations of the same data; also look into jointgrid()
# * WHAT IS A KERNEL DENISITY ESTIMATE?
# * categorical plots
#     * catplot()
#     * box-and-whisker; boxen; violin plot; swarm plot; bar plot; point plot
#     * kind argument

# %%
#1. How do you import the Seaborn package in Python?

import seaborn 

#2. How do you create a scatter plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

seaborn.scatterplot(
    data = df,
    x='x', 
    y='y'
);

#3. How do you create a line plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

seaborn.lineplot(
    data = df,
    x='x',
    y='y'
);

#4. How do you create a histogram in Seaborn for a variable `x` in a DataFrame `df`?

seaborn.histplot(
    data = df,
    x='x'
). set(
    title='My Title',
    xlabel='X Label',
    ylabel='Y Label'

);

#5. How do you create a stacked histogram in Seaborn for variables `x` and 'hue' `y` in a DataFrame `df`?

seaborn.displot (
    df,
    x='x',
    hue='y',
    multiple='stack'  
).set(
    title='My Title',
    xlabel='X Label',
    ylabel='Y Label'

);

#6. How do you create a heatmap in Seaborn for a variable `x` and `y` in a DataFrame `df`?
    #add y var to displot
seaborn.displot(
    df,
    x = 'x',
    y = 'y',
    cbar = True
) .set(
    title = 'My Title',
    xlabel = 'X Label',
    ylabel = 'Y Label'
);
#7. How do you create a box plot in Seaborn for variables `x` and `y` in a DataFrame `df`?
seaborn.catplot(
    data=df,
    x='x',
    y='y',
    kind='box'
).set(
    title='My Title',
    xlabel='X Label',
    ylabel='Y Label'
);

#8. How do you create a violin plot in Seaborn for variables `x` and `y` in a DataFrame `df`?
seaborn.catplot(
    data=df,
    x='x',
    y='y',
    kind='violin'
).set(
    title='Insert Title',
    xlabel='X Label',
    ylabel='Y Label'
);

#9. How do you create a bar plot in Seaborn for variables `x` and `y` in a DataFrame `df`?
seaborn.catplot(
    data=df,
    x='x',
    hue='y',
    kind='count'
).set(
    title='My Title',
    xlabel='X Label',
    ylabel='Y Label'
);
#10. How do you add a title to a Seaborn plot assigned to the variable `ax` with the title 'My Title'?
ax.set_title('My Title')
#11. How do you save a Seaborn plot `ax` to a file named 'output.png'?
ax.savefig('output.png')
#12. How do you set the `x` and `y` axis labels to 'X Label' and 'Y Label' respectively for a Seaborn plot `ax`?
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
#13. How do you change the color palette of a Seaborn plot to 'Blues'?
PlotName.set_palette('Blues')
#14. How do you display a Seaborn plot with a logarithmic scale on the y-axis?
PlotName.set(yscale='log')
#15. How do you add a regression line to a scatter plot in Seaborn for variables `x` and `y` in a DataFrame `df`?
seaborn.scatterplot(
    data = df,
    x='x', 
    y='y',
    kind='reg'
);
# Out:
#   Cell In[1], line 15
#     seaborn.lineplot(
#                     ^
# SyntaxError: '(' was never closed

# %%
#11. How do you save a Seaborn plot `ax` to a file named 'output.png'?
